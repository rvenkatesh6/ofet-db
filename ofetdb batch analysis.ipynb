# %%
from crud_functions import *
import pandas as pd
import numpy as np

# %%
uri = "mongodb+srv://aliu319:LO9UfXxBfDEPPfcQ@aliu319-gt.t7rt0.mongodb.net/test?retryWrites=true&w=majority"
db = "ofet-db"
collection = "sandbox"

all_docs = read_mongo_docs(uri, db, collection, proj={'_id': False})
df = pd.json_normalize(all_docs)
keys = df.columns

# %%
df[df.columns[df.dtypes == 'object']]
# Out:
#     coating_process.coating_environment coating_process.deposition_method  \
# 0                                   Air                              SPUN
# 1                                   Air                              SPUN
# 2                                   Air                              SPUN
# 3                                   Air                              SPUN
# 4                                   Air                              SPUN
# ..                                  ...                               ...
# 222                                 Air                              SPUN
# 223                                 Air                              SPUN
# 224                                 Air                              SPUN
# 225                                 Air                              SPUN
# 226                                 Air                              SPUN
#
#     literature.author                 literature.DOI ofet.environment  \
# ...
