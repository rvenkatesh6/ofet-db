# %% [markdown]
# ## ofet-db CRUD executions
#
# This notebook provides some of the basic create, read, update, and delete (CRUD) operations to interact with the ofet-db device repository

# %% [markdown]
# ### Import Libraries and Connect to ofet-db
# This block will import some of the main libraries required to interact with ofet-db (through MongoDB), plus some of the basic functions to connect to the database

# %%
from crud_functions import *
import bson
import bson.json_util

uri = "mongodb+srv://aliu319:LO9UfXxBfDEPPfcQ@aliu319-gt.t7rt0.mongodb.net/test?retryWrites=true&w=majority"
db = "ofet-db"
collection = "sandbox"

# %% [markdown]
# ### Example with inserting P3HT dataset
#
# Note that _id is not filled in an original dataset. This is kept updated as new rows are added

# %%
mydb = connect_mongo(uri=uri, db=db)
col = mydb[collection]
df_persson = pd.read_csv('data/P3HT_literature_dataset_feed.csv')
df_persson
# Out:
#     literature.author  literature.year          literature.DOI  \
# 0               Aiyar             2011  10.1002/adfm.201002729
# 1               Aiyar             2011  10.1002/adfm.201002729
# 2               Aiyar             2011  10.1002/adfm.201002729
# 3               Aiyar             2011  10.1002/adfm.201002729
# 4               Aiyar             2011  10.1002/adfm.201002729
# ..                ...              ...                     ...
# 213              Zhao             2013  10.1002/adfm.201301007
# 214              Zhao             2013  10.1002/adfm.201301007
# 215              Zhao             2013  10.1002/adfm.201301007
# 216              Zhao             2013  10.1002/adfm.201301007
# 217              Zhao             2013  10.1002/adfm.201301007
#
#      solution.polymer.semiconductor.Mn_kDa  \
# 0                                     24.0
# 1                                     24.0
# 2                                     24.0
# 3                                     24.0
# 4                                     24.0
# ..                                     ...
# 213                                   68.0
# 214                                   68.0
# 215                                   68.0
# 216                                   68.0
# 217                                   68.0
#
#      solution.polymer.semiconductor.Mw_kDa  \
# 0                                     47.7
# 1                                     47.7
# 2                                     47.7
# 3                                     47.7
# 4                                     47.7
# ..                                     ...
# 213                                  163.2
# 214                                  163.2
# 215                                  163.2
# 216                                  163.2
# 217                                  163.2
#
#      solution.polymer.semiconductor.PDI  solution.polymer.semiconductor.RR  \
# 0                                1.9875                               93.0
# 1                                1.9875                               93.0
# 2                                1.9875                               93.0
# 3                                1.9875                               93.0
# 4                                1.9875                               93.0
# ..                                  ...                                ...
# 213                              2.4000                               90.0
# 214                              2.4000                               90.0
# 215                              2.4000                               90.0
# 216                              2.4000                               90.0
# 217                              2.4000                               90.0
#
#      solution.concentration_mg_ml solution.solvent.name  \
# 0                             4.0                 CHCl3
# 1                             4.0                 CHCl3
# 2                             4.0                 CHCl3
# 3                             4.0                 CHCl3
# 4                             4.0                 CHCl3
# ..                            ...                   ...
# 213                           3.5               Toluene
# 214                           3.5               Toluene
# 215                           3.5               Toluene
# 216                           3.5               Toluene
# 217                           3.5               Toluene
#
#     solution.treatment.poorsolvent.name  ...  \
# 0                                   NaN  ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
# ..                                  ...  ...
# 213                                 NaN  ...
# 214                                 NaN  ...
# 215                                 NaN  ...
# 216                                 NaN  ...
# 217                                 NaN  ...
#
#      coating_process.annealing.temp_C  ofet.environment  ofet.regime  \
# 0                                 NaN               Air       Linear
# 1                                 NaN               Air       Linear
# 2                                 NaN               Air       Linear
# 3                                 NaN               Air       Linear
# 4                                 NaN               Air       Linear
# ..                                ...               ...          ...
# 213                               NaN               Air   Saturation
# 214                               NaN               Air   Saturation
# 215                               NaN               Air   Saturation
# 216                               NaN               Air   Saturation
# 217                               NaN               Air   Saturation
#
#      substrate.electrode_config  substrate.channel_length_um  \
# 0                          BGBC                         50.0
# 1                          BGBC                         50.0
# 2                          BGBC                         50.0
# 3                          BGBC                         50.0
# 4                          BGBC                         50.0
# ..                          ...                          ...
# 213                        BGTC                         30.0
# 214                        BGTC                         30.0
# 215                        BGTC                         30.0
# 216                        BGTC                         30.0
# 217                        BGTC                         30.0
#
#     substrate.channel_width_mm ofet.Vds_V  substrate.electrode_material  \
# 0                          2.0       -3.0                            Au
# 1                          2.0       -3.0                            Au
# 2                          2.0       -3.0                            Au
# 3                          2.0       -3.0                            Au
# 4                          2.0       -3.0                            Au
# ..                         ...        ...                           ...
# 213                        0.5        NaN                            Au
# 214                        0.5        NaN                            Au
# 215                        0.5        NaN                            Au
# 216                        0.5        NaN                            Au
# 217                        0.5        NaN                            Au
#
#      coating_process.deposition_method  ofet.mobility_cm2_Vs
# 0                                 SPUN              0.000202
# 1                                 SPUN              0.007190
# 2                                 SPUN              0.029400
# 3                                 SPUN              0.050600
# 4                                 SPUN              0.030600
# ..                                 ...                   ...
# 213                               SPUN              0.001020
# 214                               SPUN              0.003050
# 215                               SPUN              0.008030
# 216                               SPUN              0.009530
# 217                               SPUN              0.009150
#
# [218 rows x 33 columns]

# %%
matchedCount = 0
modifiedCount = 0
for i, row_i in df_persson.iterrows():
    nextDict = row_to_json(row_i) #custom function will only add column names with a reported entry
    json_i = bson.json_util.dumps(nextDict, cls=NpEncoder)
    doc_i = bson.json_util.loads(json_i)
    cur = col.update_one(doc_i, {"$set": doc_i}, upsert=True)
    matchedCount+=cur.matched_count
    modifiedCount+=cur.modified_count
print("Number of matched entries (upserted): %s \nNumber of modified entries: %s"  % (matchedCount, modifiedCount))
# Out:
# Number of matched entries (upserted): 214
# Number of modified entries: 0

# %% [markdown]
# ### Example with inserting rows from a literature batch
#
# This is an example of a batch insert using an Excel data recording template. This example is from Chu et al. (2016). The Excel columns are formatted in dot notation to match the schema of ofet-db. For example, `solution.solvent.name` will be embedded at the third level of a JSON document.

# %%
df_chang = pd.read_excel('data\kleinhenz2016_dataentry.xlsx')
df_chang
# Out:
#    _id  ofet.mobility_cm2_Vs  ofet.Vthreshold_V  ofet.I_on_off ofet.regime  \
# 0  NaN                0.0130                NaN            NaN  saturation
# 1  NaN                0.0894                NaN            NaN  saturation
# 2  NaN                0.1091                NaN            NaN  saturation
# 3  NaN                0.0905                NaN            NaN  saturation
# 4  NaN                0.1016                NaN            NaN  saturation
# 5  NaN                0.1113                NaN            NaN  saturation
# 6  NaN                0.1490                NaN            NaN  saturation
# 7  NaN                0.0867                NaN            NaN  saturation
#
#   ofet.environment  ofet.Vds_V solution.solvent.name  \
# 0               N2         -80                 CHCl3
# 1               N2         -80                 CHCl3
# 2               N2         -80                 CHCl3
# 3               N2         -80                 CHCl3
# 4               N2         -80                 CHCl3
# 5               N2         -80                 CHCl3
# 6               N2         -80                 CHCl3
# 7               N2         -80                 CHCl3
#
#    solution.solvent.boiling_point_C solution.polymer.semiconductor.name  ...  \
# 0                                61                                P3HT  ...
# 1                                61                                P3HT  ...
# 2                                61                                P3HT  ...
# 3                                61                                P3HT  ...
# 4                                61                                P3HT  ...
# 5                                61                                P3HT  ...
# 6                                61                                P3HT  ...
# 7                                61                                P3HT  ...
#
#    film.uv_vis.dichroic_ratio  film.thickness_nm  film.giwaxs.grain_size_nm  \
# 0                         NaN                NaN                      81.37
# 1                         NaN                NaN                      97.30
# 2                         NaN                NaN                     108.60
# 3                         NaN                NaN                     107.70
# 4                         NaN                NaN                     112.10
# 5                         NaN                NaN                     110.70
# 6                         NaN                NaN                     104.20
# 7                         NaN                NaN                      91.30
#
#    film.giwaxs.hermans_orientation_factor  film.giwaxs.010_spacing_A  \
# 0                                   0.296                     3.6478
# 1                                   0.616                     3.6423
# 2                                   0.461                     3.6633
# 3                                   0.688                     3.6417
# 4                                   0.736                     3.6280
# 5                                   0.428                     3.6463
# 6                                   0.775                     3.6470
# 7                                   0.659                     3.6497
#
#    film.giwaxs.100_spacing_A  film.afm.S2D  film.afm.correlation_length_nm  \
# 0                      16.22  5.707300e-01                        329.8731
# 1                      16.14  8.136400e-01                        514.4511
# 2                      16.57  3.485600e-01                       2952.3459
# 3                      16.14  7.788300e-01                        344.0449
# 4                      16.07  4.187300e-01                       1291.5042
# 5                      16.42  6.384500e-02                        710.4933
# 6                      16.02  7.393800e-02                       1636.7884
# 7                      16.06  1.008800e-11                       1495.7216
#
#    film.afm.fiber_length_density_1_um  film.afm.mean_fiber_length_nm
# 0                              3.6108                       177.5610
# 1                              6.0109                       322.4670
# 2                              6.4005                       312.0000
# 3                              5.8029                       269.8842
# 4                              5.5742                       250.2602
# 5                              4.4305                       204.2966
# 6                              5.3320                       270.0000
# 7                              5.3379                       291.2556
#
# [8 rows x 56 columns]

# %%
matchedCount = 0
modifiedCount = 0
for i, row_i in df_chang.iterrows():
    nextDict = row_to_json(row_i) #custom function will only add column names with a reported entry
    json_i = bson.json_util.dumps(nextDict, cls=NpEncoder)
    doc_i = bson.json_util.loads(json_i)
    cur = col.update_one(doc_i, {"$set": doc_i}, upsert=True)
    matchedCount+=cur.matched_count
    modifiedCount+=cur.modified_count
print("Number of matched entries (upserted): %s \nNumber of modified entries: %s"  % (matchedCount, modifiedCount))
# Out:
# Number of matched entries (upserted): 8
# Number of modified entries: 0

# %%
# a = bson.json_util.dumps(df_chu)
# docs = bson.json_util.loads(a)
# cur = col.update_one(doc_i, {"$set": doc_i}, upsert=True)
# Out:
#   File "<ipython-input-45-b4b2d745ab41>", line 9
#     return result.matched_count > 0
#     ^
# SyntaxError: 'return' outside function

# %%
my_doc = bson.json_util.loads(json_i)
# my_doc
col.update_one(my_doc, {"$set": my_doc}, upsert=True)

# %%
help(cur)
# Out:
# Help on UpdateResult in module pymongo.results object:
#
# class UpdateResult(_WriteResult)
#  |  UpdateResult(raw_result, acknowledged)
#  |
#  |  The return type for :meth:`~pymongo.collection.Collection.update_one`,
#  |  :meth:`~pymongo.collection.Collection.update_many`, and
#  |  :meth:`~pymongo.collection.Collection.replace_one`.
#  |
#  |  Method resolution order:
#  |      UpdateResult
#  |      _WriteResult
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, raw_result, acknowledged)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  matched_count
#  |      The number of documents matched for this update.
#  |
#  |  modified_count
#  |      The number of documents modified.
#  |
#  |      .. note:: modified_count is only reported by MongoDB 2.6 and later.
#  |        When connected to an earlier server version, or in certain mixed
#  |        version sharding configurations, this attribute will be set to
#  |        ``None``.
#  |
#  |  raw_result
#  |      The raw result document returned by the server.
#  |
#  |  upserted_id
#  |      The _id of the inserted document if an upsert took place. Otherwise
#  |      ``None``.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from _WriteResult:
#  |
#  |  acknowledged
#  |      Is this the result of an acknowledged write operation?
#  |
#  |      The :attr:`acknowledged` attribute will be ``False`` when using
#  |      ``WriteConcern(w=0)``, otherwise ``True``.
#  |
#  |      .. note::
#  |        If the :attr:`acknowledged` attribute is ``False`` all other
#  |        attibutes of this class will raise
#  |        :class:`~pymongo.errors.InvalidOperation` when accessed. Values for
#  |        other attributes cannot be determined if the write operation was
#  |        unacknowledged.
#  |
#  |      .. seealso::
#  |        :class:`~pymongo.write_concern.WriteConcern`

# %%
json_i
# Out:
# '{"ofet": {"mobility_cm2_Vs": 0.1218, "regime": "saturation", "environment": "N2"}, "solution": {"solvent": {"name": "chloroform", "boiling_point_C": 61}, "polymer": {"semiconductor": {"name": "P3HT", "Mw_kDa": 90, "RR": 96, "x_wt": 1}}, "concentration_mg_ml": 5, "treatment": {"age": {"time_hr": 24, "temp_C": 25}, "UV": {"time_min": 8, "wavelength": 254}, "sonication_min": 0}, "uv_vis": {"pct_aggregates": 21.9}}, "substrate": {"gate_material": "Si", "dielectric_material": "SiO11", "electrode_config": "BGBC", "electrode_material": "Au", "channel_length_um": 50, "channel_width_mm": 2, "surface_modification": "None"}, "coating_process": {"deposition_method": "SPUN", "spin_rate_rpm": 1500.0, "spin_time_s": 60.0, "coating_environment": "Air"}, "literature": {"author": "Chu", "year": 2016, "DOI": "10.1021/acs.chemmater.6b04202"}, "film": {"uv_vis": {"exciton_bandwidth_meV": 47.6, "dichroic_ratio": 1.17}}}'

# %%
docs = read_mongo_docs(uri, db, collection, proj={"literature": 1})

temp = pd.json_normalize(docs)
temp
# Out:
#                         _id literature.author  literature.year  \
# 0  629f5281c12fd58f665a5648               Chu             2016
# 1  629f5282c12fd58f665a5649               Chu             2016
# 2  629f5282c12fd58f665a564a               Chu             2016
# 3  629f5282c12fd58f665a564b               Chu             2016
# 4  629f5282c12fd58f665a564c               Chu             2016
# 5  629f5282c12fd58f665a564d               Chu             2016
# 6  629f5282c12fd58f665a564e               Chu             2016
# 7  629f5282c12fd58f665a564f               Chu             2016
# 8  629f5282c12fd58f665a5650               Chu             2016
# 9  629f5282c12fd58f665a5651               Chu             2016
#
#                   literature.DOI
# 0  10.1021/acs.chemmater.6b04202
# 1  10.1021/acs.chemmater.6b04202
# 2  10.1021/acs.chemmater.6b04202
# 3  10.1021/acs.chemmater.6b04202
# 4  10.1021/acs.chemmater.6b04202
# 5  10.1021/acs.chemmater.6b04202
# 6  10.1021/acs.chemmater.6b04202
# 7  10.1021/acs.chemmater.6b04202
# 8  10.1021/acs.chemmater.6b04202
# 9  10.1021/acs.chemmater.6b04202

# %%
query = {'solution.solvent.boiling_point_C': 61}
proj = {'_id': 0, 'solution.polymer': 1}

df = read_mongo(uri=uri, db=db, collection=collection, query=query, proj=proj)
df
# Out:
#     solution.polymer.semiconductor.Mw_kDa  \
# 0                                  47.700
# 1                                  47.700
# 2                                  47.700
# 3                                  47.700
# 4                                  47.700
# ..                                    ...
# 82                                  6.608
# 83                                 20.424
# 84                                 20.424
# 85                                 25.650
# 86                                 25.650
#
#     solution.polymer.semiconductor.Mn_kDa  solution.polymer.semiconductor.PDI  \
# 0                                    24.0                              1.9875
# 1                                    24.0                              1.9875
# 2                                    24.0                              1.9875
# 3                                    24.0                              1.9875
# 4                                    24.0                              1.9875
# ..                                    ...                                 ...
# 82                                    5.6                              1.1800
# 83                                   13.8                              1.4800
# 84                                   13.8                              1.4800
# 85                                   19.0                              1.3500
# 86                                   19.0                              1.3500
#
#     solution.polymer.semiconductor.RR solution.polymer.semiconductor.name  \
# 0                                93.0                                P3HT
# 1                                93.0                                P3HT
# 2                                93.0                                P3HT
# 3                                93.0                                P3HT
# 4                                93.0                                P3HT
# ..                                ...                                 ...
# 82                               91.0                                P3HT
# 83                               91.0                                P3HT
# 84                               91.0                                P3HT
# 85                               91.0                                P3HT
# 86                               91.0                                P3HT
#
#     solution.polymer.semiconductor.x_wt
# 0                                   1.0
# 1                                   1.0
# 2                                   1.0
# 3                                   1.0
# 4                                   1.0
# ..                                  ...
# 82                                  1.0
# 83                                  1.0
# 84                                  1.0
# 85                                  1.0
# 86                                  1.0
#
# [87 rows x 6 columns]

# %%
mydb = _connect_mongo(uri=uri, db=db)
col = mydb["devices"]
cursor = col.find({})
type(list(cursor)[0])
# Out:
# dict

# %%
import json
from bson.objectid import ObjectId

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        if isinstance(obj, np.nan):
            return None
        return super(NpEncoder, self).default(obj)

def get_sample_dict(sample_row):
     
    sample_dict = {
        {
            "name": "P3HT",
            "Mn_kDa": sample_row.Mn_kDa,
            "Mw_kDa": sample_row.Mw_kDa,
            "PDI": sample_row.PDI,
            "RR": sample_row.RR,
            "x_wt": 1.0
        }
    }
    
    return sample_dict

# %%
df = pd.read_csv('data/P3HT_literature_dataset_feed.csv')
df
# Out:
#      Unnamed: 0                       _id Author  Year  \
# 0             0  627d547b973eca8e8a04e96f  Aiyar  2011
# 1             1  627d547b973eca8e8a04e970  Aiyar  2011
# 2             2  627d547b973eca8e8a04e971  Aiyar  2011
# 3             3  627d547b973eca8e8a04e972  Aiyar  2011
# 4             4  627d547c973eca8e8a04e973  Aiyar  2011
# ..          ...                       ...    ...   ...
# 123         123  627d5481973eca8e8a04e9ea   Zhao  2013
# 124         124  627d5481973eca8e8a04e9eb   Zhao  2013
# 125         125  627d5481973eca8e8a04e9ec   Zhao  2013
# 126         126  627d5481973eca8e8a04e9ed   Zhao  2013
# 127         127  627d5481973eca8e8a04e9ee   Zhao  2013
#
#                         DOI  Mn_kDa  Mw_kDa     PDI    RR  \
# 0    10.1002/adfm.201002729    24.0    47.7  1.9875  93.0
# 1    10.1002/adfm.201002729    24.0    47.7  1.9875  93.0
# 2    10.1002/adfm.201002729    24.0    47.7  1.9875  93.0
# 3    10.1002/adfm.201002729    24.0    47.7  1.9875  93.0
# 4    10.1002/adfm.201002729    24.0    47.7  1.9875  93.0
# ..                      ...     ...     ...     ...   ...
# 123  10.1002/adfm.201301007    68.0   163.2  2.4000  90.0
# 124  10.1002/adfm.201301007    68.0   163.2  2.4000  90.0
# 125  10.1002/adfm.201301007    68.0   163.2  2.4000  90.0
# 126  10.1002/adfm.201301007    68.0   163.2  2.4000  90.0
# 127  10.1002/adfm.201301007    68.0   163.2  2.4000  90.0
#
#      solution_concentration_mg_ml  ... anneal_time_hr  mobility_environment  \
# 0                             4.0  ...            NaN                   Air
# 1                             4.0  ...            NaN                   Air
# 2                             4.0  ...            NaN                   Air
# 3                             4.0  ...            NaN                   Air
# 4                             4.0  ...            NaN                   Air
# ..                            ...  ...            ...                   ...
# 123                           3.5  ...            NaN                   Air
# 124                           3.5  ...            NaN                   Air
# 125                           3.5  ...            NaN                   Air
# 126                           3.5  ...            NaN                   Air
# 127                           3.5  ...            NaN                   Air
#
#      mobility_regime  electrode_config  channel_length_um channel_width_mm  \
# 0             Linear              BGBC               50.0              2.0
# 1             Linear              BGBC               50.0              2.0
# 2             Linear              BGBC               50.0              2.0
# 3             Linear              BGBC               50.0              2.0
# 4             Linear              BGBC               50.0              2.0
# ..               ...               ...                ...              ...
# 123       Saturation              BGTC               30.0              0.5
# 124       Saturation              BGTC               30.0              0.5
# 125       Saturation              BGTC               30.0              0.5
# 126       Saturation              BGTC               30.0              0.5
# 127       Saturation              BGTC               30.0              0.5
#
#     Vds_V  electrode_material  deposition_method  mobility_cm2_Vs
# 0    -3.0                  Au               SPUN         0.000202
# 1    -3.0                  Au               SPUN         0.007190
# 2    -3.0                  Au               SPUN         0.029400
# 3    -3.0                  Au               SPUN         0.050600
# 4    -3.0                  Au               SPUN         0.030600
# ..    ...                 ...                ...              ...
# 123   NaN                  Au               SPUN         0.001020
# 124   NaN                  Au               SPUN         0.003050
# 125   NaN                  Au               SPUN         0.008030
# 126   NaN                  Au               SPUN         0.009530
# 127   NaN                  Au               SPUN         0.009150
#
# [128 rows x 33 columns]

# %%
mydb = _connect_mongo(uri=uri, db=db)
col = mydb["devices"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3beea0341b30> in <module>
# ----> 1 mydb = _connect_mongo(uri=uri, db=db)
#       2 col = mydb["devices"]
#
# NameError: name '_connect_mongo' is not defined

# %%
for i in df.index:

    row_i = df.iloc[i]
    _id_i = row_i['_id']
    col.find_one_and_update(
        {
            "_id": ObjectId(_id_i)
        }, 
        {
            "$set": {
                'solution.polymer.semiconductor.name': "P3HT",
                'solution.polymer.semiconductor.Mn_kDa': row_i.Mn_kDa,
                'solution.polymer.semiconductor.Mw_kDa': row_i.Mw_kDa,
                'solution.polymer.semiconductor.PDI': row_i.PDI,
                'solution.polymer.semiconductor.RR': row_i.RR,
                'solution.polymer.semiconductor.x_wt': 1.0
            }
        }
    )
